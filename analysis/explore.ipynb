# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

pd.set_option("display.max_columns", 60)
pd.set_option("display.width", 140)
pd.set_option("display.max_rows", 30)

# %%
# Notebook lives in /analysis, data lives in repo root
ROOT = Path("..")

print("Notebook cwd:", Path.cwd())
print("Repo root:", ROOT.resolve())

df = pd.read_csv(ROOT / "kalshi_markets_with_indicators.csv")

print("Rows:", len(df), "Columns:", len(df.columns))
df.head()
# Out:
# Notebook cwd: /workspaces/kalshi-market-data/analysis
# Repo root: /workspaces/kalshi-market-data
# Rows: 100 Columns: 36
#       timestamp                                              title                                   event_ticker  category  status  \
# 0  1.769247e+09    yes Donovan Mitchell: 2+,yes Paolo Banchero: 6+            KXMVENBASINGLEGAME-S2025445BD5BA7BC       NaN  active
# 1  1.769247e+09  yes Donovan Mitchell: 2+,yes Paolo Banchero: 2...            KXMVENBASINGLEGAME-S20255BD6546A053       NaN  active
# 2  1.769247e+09  yes Paolo Banchero: 2+,yes Donovan Mitchell: 2...            KXMVENBASINGLEGAME-S2025C1D88E8AC53       NaN  active
# 3  1.769247e+09  yes Paolo Banchero: 2+,yes Donovan Mitchell: 2...            KXMVENBASINGLEGAME-S2025E55B4B729FB       NaN  active
# 4  1.769247e+09  yes Draymond Green: 2+,yes Stephen Curry: 2+,y...  KXMVESPORTSMULTIGAMEEXTENDED-S2025022B59C2074       NaN  active
#
#              close_time  yes_bid  yes_ask  no_bid  no_ask  volume  open_interest  last_trade_price  has_yes_book  has_no_book  mid_yes  \
# 0  2026-02-08T00:00:00Z        0        0     100     100       0              0               NaN         False         True      NaN
# 1  2026-02-08T00:00:00Z        0        0     100     100       0              0               NaN         False         True      NaN
# 2  2026-02-08T00:00:00Z        0        0     100     100       0              0               NaN         False         True      NaN
# 3  2026-02-08T00:00:00Z        0        0     100     100       0              0               NaN         False         True      NaN
# 4  2026-02-07T22:30:00Z        0        0     100     100       0              0               NaN         False         True      NaN
#
#    mid_no  spread_yes  spread_no  rel_spread_yes  p_yes  overround  tte_hours  d_volume  d_open_interest  delta_p  z_p  vol_p  range_p  \
# 0     1.0         NaN        0.0             NaN    NaN        NaN        NaN       NaN              NaN      NaN  NaN    NaN      NaN
# 1     1.0         NaN        0.0             NaN    NaN        NaN        NaN       NaN              NaN      NaN  NaN    NaN      NaN
# 2     1.0         NaN        0.0             NaN    NaN        NaN        NaN       NaN              NaN      NaN  NaN    NaN      NaN
# 3     1.0         NaN        0.0             NaN    NaN        NaN        NaN       NaN              NaN      NaN  NaN    NaN      NaN
# 4     1.0         NaN        0.0             NaN    NaN        NaN        NaN       NaN              NaN      NaN  NaN    NaN      NaN
#
#    momentum_p  ema_fast  ema_slow  ema_diff  accel_p  near_bounds  is_unchanged
# 0         NaN       NaN       NaN       NaN      NaN        False         False
# 1         NaN       NaN       NaN       NaN      NaN        False         False
# 2         NaN       NaN       NaN       NaN      NaN        False         False
# 3         NaN       NaN       NaN       NaN      NaN        False         False
# 4         NaN       NaN       NaN       NaN      NaN        False         False

# %%
sorted(df.columns)
# Out:
# ['accel_p',
#  'category',
#  'close_time',
#  'd_open_interest',
#  'd_volume',
#  'delta_p',
#  'ema_diff',
#  'ema_fast',
#  'ema_slow',
#  'event_ticker',
#  'has_no_book',
#  'has_yes_book',
#  'is_unchanged',
#  'last_trade_price',
#  'mid_no',
#  'mid_yes',
#  'momentum_p',
#  'near_bounds',
#  'no_ask',
#  'no_bid',
#  'open_interest',
#  'overround',
#  'p_yes',
#  'range_p',
#  'rel_spread_yes',
#  'spread_no',
#  'spread_yes',
#  'status',
#  'timestamp',
#  'title',
#  'tte_hours',
#  'vol_p',
#  'volume',
#  'yes_ask',
#  'yes_bid',
#  'z_p']
